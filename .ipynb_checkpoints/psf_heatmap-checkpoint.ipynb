# %%
import re
import os

from scipy.interpolate import griddata
from pykrige.ok import OrdinaryKriging
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.colors as mcolors

# %%
def is_numeric(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

# %%
images_directory = "ZeissGreenBeadsIMG4R" #

# %%
cmap = mcolors.LinearSegmentedColormap.from_list("custom_cmap", ["darkblue", "lightblue", "lightgreen", "orange", "red"])

vmin = 0
vmax = 2

# %%
x_ratios = []
y_ratios = []
z_ratios = []
lateral_asymmetries = []

items = os.listdir(images_directory)
image_folders = [item for item in items if os.path.isdir(os.path.join(images_directory, item)) and re.match(r'^Image \d+$', item)]

beads_list = []

for image in image_folders:
    image_path = os.path.join(images_directory, image)
    bead_folders = [item for item in os.listdir(image_path) if os.path.isdir(os.path.join(image_path, item)) and re.match(r'^bead\d+$', item)]

    for bead in bead_folders:
        data_folder = f"{images_directory}_{image}_{bead}_data"
        file_path = os.path.join(image_path, bead, data_folder)
        xls_file_path = os.path.join(file_path, f"{images_directory}_{image}_{bead}_results.xls")
        
        try:
            with open(xls_file_path, 'r') as file:
                data = file.read()
                
                result = {
                    "Image": image,
                    "Bead": bead,
                    "Mes./theory ratio": {},
                    "Lateral Asymmetry": None,
                    "Bead coordinates (pixels)": {}
                }
            
                lines = data.split('\n')
                resolution_table_start = False
                lateral_asymmetry_table_start = False
                
                for line in lines:
                    
                    if "Bead original coordinates(in pixels)" in line:
                        coords = line.split('\t')[2].strip()
                        if coords:
                            try:
                                x, y = map(float, coords.split(', '))
                                result["Bead coordinates (pixels)"]["X"] = x
                                result["Bead coordinates (pixels)"]["Y"] = y
                            except ValueError:
                                print(f"Invalid coordinates for {image}/{bead}")
                                
                    if "Resolution" in line:
                        resolution_table_start = True
                        continue

                    if resolution_table_start and line.strip() and line.split("\t")[0] != "Channel":
                        parts = line.split('\t')
                        if len(parts) >= 7:
                            dimension = parts[2]
                            ratio = parts[6]
                            if is_numeric(ratio):
                                ratio_value = float(ratio)
                                result["Mes./theory ratio"][dimension] = ratio_value
                                
                                # Append values to the respective lists
                                if dimension == 'X':
                                    x_ratios.append(ratio_value)
                                elif dimension == 'Y':
                                    y_ratios.append(ratio_value)
                                elif dimension == 'Z':
                                    z_ratios.append(ratio_value)
                    
                    if "Lateral Asymmetry" in line:
                        lateral_asymmetry_table_start = True
                        continue
                    
                    if lateral_asymmetry_table_start and line.strip().startswith("Channel 0") and line.strip():
                        parts = line.split('\t')
                        if len(parts) >= 2:
                            asymmetry = parts[1]
                            if is_numeric(asymmetry):
                                asymmetry_value = float(asymmetry)
                                result["Lateral Asymmetry"] = asymmetry_value
                                # Append to lateral asymmetries list
                                lateral_asymmetries.append(asymmetry_value)
                        break  
                    
            beads_list.append(result)

        except FileNotFoundError:
            print(f"\nError: {xls_file_path} not found")
        except Exception as e:
            print(f"\nError processing {xls_file_path}: {str(e)}")

# Print the lists of values
print("X Ratios:", x_ratios)
print("Y Ratios:", y_ratios)
print("Z Ratios:", z_ratios)
print("Lateral Asymmetries:", lateral_asymmetries)
# Out:
# Error: ZeissGreenBeadsIMG4R/Image 4/bead17/ZeissGreenBeadsIMG4R_Image 4_bead17_data/ZeissGreenBeadsIMG4R_Image 4_bead17_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 4/bead10/ZeissGreenBeadsIMG4R_Image 4_bead10_data/ZeissGreenBeadsIMG4R_Image 4_bead10_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 4/bead11/ZeissGreenBeadsIMG4R_Image 4_bead11_data/ZeissGreenBeadsIMG4R_Image 4_bead11_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 4/bead16/ZeissGreenBeadsIMG4R_Image 4_bead16_data/ZeissGreenBeadsIMG4R_Image 4_bead16_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 4/bead5/ZeissGreenBeadsIMG4R_Image 4_bead5_data/ZeissGreenBeadsIMG4R_Image 4_bead5_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 4/bead2/ZeissGreenBeadsIMG4R_Image 4_bead2_data/ZeissGreenBeadsIMG4R_Image 4_bead2_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 4/bead3/ZeissGreenBeadsIMG4R_Image 4_bead3_data/ZeissGreenBeadsIMG4R_Image 4_bead3_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 4/bead4/ZeissGreenBeadsIMG4R_Image 4_bead4_data/ZeissGreenBeadsIMG4R_Image 4_bead4_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 4/bead13/ZeissGreenBeadsIMG4R_Image 4_bead13_data/ZeissGreenBeadsIMG4R_Image 4_bead13_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 4/bead14/ZeissGreenBeadsIMG4R_Image 4_bead14_data/ZeissGreenBeadsIMG4R_Image 4_bead14_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 4/bead15/ZeissGreenBeadsIMG4R_Image 4_bead15_data/ZeissGreenBeadsIMG4R_Image 4_bead15_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 4/bead12/ZeissGreenBeadsIMG4R_Image 4_bead12_data/ZeissGreenBeadsIMG4R_Image 4_bead12_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 4/bead8/ZeissGreenBeadsIMG4R_Image 4_bead8_data/ZeissGreenBeadsIMG4R_Image 4_bead8_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 4/bead1/ZeissGreenBeadsIMG4R_Image 4_bead1_data/ZeissGreenBeadsIMG4R_Image 4_bead1_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 4/bead6/ZeissGreenBeadsIMG4R_Image 4_bead6_data/ZeissGreenBeadsIMG4R_Image 4_bead6_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 4/bead7/ZeissGreenBeadsIMG4R_Image 4_bead7_data/ZeissGreenBeadsIMG4R_Image 4_bead7_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 4/bead0/ZeissGreenBeadsIMG4R_Image 4_bead0_data/ZeissGreenBeadsIMG4R_Image 4_bead0_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 4/bead9/ZeissGreenBeadsIMG4R_Image 4_bead9_data/ZeissGreenBeadsIMG4R_Image 4_bead9_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 2/bead10/ZeissGreenBeadsIMG4R_Image 2_bead10_data/ZeissGreenBeadsIMG4R_Image 2_bead10_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 2/bead11/ZeissGreenBeadsIMG4R_Image 2_bead11_data/ZeissGreenBeadsIMG4R_Image 2_bead11_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 2/bead5/ZeissGreenBeadsIMG4R_Image 2_bead5_data/ZeissGreenBeadsIMG4R_Image 2_bead5_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 2/bead2/ZeissGreenBeadsIMG4R_Image 2_bead2_data/ZeissGreenBeadsIMG4R_Image 2_bead2_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 2/bead3/ZeissGreenBeadsIMG4R_Image 2_bead3_data/ZeissGreenBeadsIMG4R_Image 2_bead3_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 2/bead4/ZeissGreenBeadsIMG4R_Image 2_bead4_data/ZeissGreenBeadsIMG4R_Image 2_bead4_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 2/bead13/ZeissGreenBeadsIMG4R_Image 2_bead13_data/ZeissGreenBeadsIMG4R_Image 2_bead13_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 2/bead14/ZeissGreenBeadsIMG4R_Image 2_bead14_data/ZeissGreenBeadsIMG4R_Image 2_bead14_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 2/bead12/ZeissGreenBeadsIMG4R_Image 2_bead12_data/ZeissGreenBeadsIMG4R_Image 2_bead12_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 2/bead8/ZeissGreenBeadsIMG4R_Image 2_bead8_data/ZeissGreenBeadsIMG4R_Image 2_bead8_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 2/bead1/ZeissGreenBeadsIMG4R_Image 2_bead1_data/ZeissGreenBeadsIMG4R_Image 2_bead1_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 2/bead6/ZeissGreenBeadsIMG4R_Image 2_bead6_data/ZeissGreenBeadsIMG4R_Image 2_bead6_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 2/bead7/ZeissGreenBeadsIMG4R_Image 2_bead7_data/ZeissGreenBeadsIMG4R_Image 2_bead7_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 2/bead0/ZeissGreenBeadsIMG4R_Image 2_bead0_data/ZeissGreenBeadsIMG4R_Image 2_bead0_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 2/bead9/ZeissGreenBeadsIMG4R_Image 2_bead9_data/ZeissGreenBeadsIMG4R_Image 2_bead9_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 5/bead10/ZeissGreenBeadsIMG4R_Image 5_bead10_data/ZeissGreenBeadsIMG4R_Image 5_bead10_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 5/bead5/ZeissGreenBeadsIMG4R_Image 5_bead5_data/ZeissGreenBeadsIMG4R_Image 5_bead5_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 5/bead2/ZeissGreenBeadsIMG4R_Image 5_bead2_data/ZeissGreenBeadsIMG4R_Image 5_bead2_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 5/bead3/ZeissGreenBeadsIMG4R_Image 5_bead3_data/ZeissGreenBeadsIMG4R_Image 5_bead3_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 5/bead4/ZeissGreenBeadsIMG4R_Image 5_bead4_data/ZeissGreenBeadsIMG4R_Image 5_bead4_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 5/bead8/ZeissGreenBeadsIMG4R_Image 5_bead8_data/ZeissGreenBeadsIMG4R_Image 5_bead8_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 5/bead1/ZeissGreenBeadsIMG4R_Image 5_bead1_data/ZeissGreenBeadsIMG4R_Image 5_bead1_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 5/bead6/ZeissGreenBeadsIMG4R_Image 5_bead6_data/ZeissGreenBeadsIMG4R_Image 5_bead6_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 5/bead7/ZeissGreenBeadsIMG4R_Image 5_bead7_data/ZeissGreenBeadsIMG4R_Image 5_bead7_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 5/bead0/ZeissGreenBeadsIMG4R_Image 5_bead0_data/ZeissGreenBeadsIMG4R_Image 5_bead0_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 5/bead9/ZeissGreenBeadsIMG4R_Image 5_bead9_data/ZeissGreenBeadsIMG4R_Image 5_bead9_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead26/ZeissGreenBeadsIMG4R_Image 9_bead26_data/ZeissGreenBeadsIMG4R_Image 9_bead26_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead19/ZeissGreenBeadsIMG4R_Image 9_bead19_data/ZeissGreenBeadsIMG4R_Image 9_bead19_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead21/ZeissGreenBeadsIMG4R_Image 9_bead21_data/ZeissGreenBeadsIMG4R_Image 9_bead21_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead17/ZeissGreenBeadsIMG4R_Image 9_bead17_data/ZeissGreenBeadsIMG4R_Image 9_bead17_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead28/ZeissGreenBeadsIMG4R_Image 9_bead28_data/ZeissGreenBeadsIMG4R_Image 9_bead28_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead10/ZeissGreenBeadsIMG4R_Image 9_bead10_data/ZeissGreenBeadsIMG4R_Image 9_bead10_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead44/ZeissGreenBeadsIMG4R_Image 9_bead44_data/ZeissGreenBeadsIMG4R_Image 9_bead44_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead43/ZeissGreenBeadsIMG4R_Image 9_bead43_data/ZeissGreenBeadsIMG4R_Image 9_bead43_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead11/ZeissGreenBeadsIMG4R_Image 9_bead11_data/ZeissGreenBeadsIMG4R_Image 9_bead11_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead16/ZeissGreenBeadsIMG4R_Image 9_bead16_data/ZeissGreenBeadsIMG4R_Image 9_bead16_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead29/ZeissGreenBeadsIMG4R_Image 9_bead29_data/ZeissGreenBeadsIMG4R_Image 9_bead29_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead20/ZeissGreenBeadsIMG4R_Image 9_bead20_data/ZeissGreenBeadsIMG4R_Image 9_bead20_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead27/ZeissGreenBeadsIMG4R_Image 9_bead27_data/ZeissGreenBeadsIMG4R_Image 9_bead27_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead18/ZeissGreenBeadsIMG4R_Image 9_bead18_data/ZeissGreenBeadsIMG4R_Image 9_bead18_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead42/ZeissGreenBeadsIMG4R_Image 9_bead42_data/ZeissGreenBeadsIMG4R_Image 9_bead42_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead45/ZeissGreenBeadsIMG4R_Image 9_bead45_data/ZeissGreenBeadsIMG4R_Image 9_bead45_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead5/ZeissGreenBeadsIMG4R_Image 9_bead5_data/ZeissGreenBeadsIMG4R_Image 9_bead5_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead2/ZeissGreenBeadsIMG4R_Image 9_bead2_data/ZeissGreenBeadsIMG4R_Image 9_bead2_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead3/ZeissGreenBeadsIMG4R_Image 9_bead3_data/ZeissGreenBeadsIMG4R_Image 9_bead3_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead4/ZeissGreenBeadsIMG4R_Image 9_bead4_data/ZeissGreenBeadsIMG4R_Image 9_bead4_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead58/ZeissGreenBeadsIMG4R_Image 9_bead58_data/ZeissGreenBeadsIMG4R_Image 9_bead58_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead56/ZeissGreenBeadsIMG4R_Image 9_bead56_data/ZeissGreenBeadsIMG4R_Image 9_bead56_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead51/ZeissGreenBeadsIMG4R_Image 9_bead51_data/ZeissGreenBeadsIMG4R_Image 9_bead51_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead34/ZeissGreenBeadsIMG4R_Image 9_bead34_data/ZeissGreenBeadsIMG4R_Image 9_bead34_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead33/ZeissGreenBeadsIMG4R_Image 9_bead33_data/ZeissGreenBeadsIMG4R_Image 9_bead33_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead50/ZeissGreenBeadsIMG4R_Image 9_bead50_data/ZeissGreenBeadsIMG4R_Image 9_bead50_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead57/ZeissGreenBeadsIMG4R_Image 9_bead57_data/ZeissGreenBeadsIMG4R_Image 9_bead57_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead59/ZeissGreenBeadsIMG4R_Image 9_bead59_data/ZeissGreenBeadsIMG4R_Image 9_bead59_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead32/ZeissGreenBeadsIMG4R_Image 9_bead32_data/ZeissGreenBeadsIMG4R_Image 9_bead32_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead35/ZeissGreenBeadsIMG4R_Image 9_bead35_data/ZeissGreenBeadsIMG4R_Image 9_bead35_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead40/ZeissGreenBeadsIMG4R_Image 9_bead40_data/ZeissGreenBeadsIMG4R_Image 9_bead40_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead47/ZeissGreenBeadsIMG4R_Image 9_bead47_data/ZeissGreenBeadsIMG4R_Image 9_bead47_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead49/ZeissGreenBeadsIMG4R_Image 9_bead49_data/ZeissGreenBeadsIMG4R_Image 9_bead49_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead22/ZeissGreenBeadsIMG4R_Image 9_bead22_data/ZeissGreenBeadsIMG4R_Image 9_bead22_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead25/ZeissGreenBeadsIMG4R_Image 9_bead25_data/ZeissGreenBeadsIMG4R_Image 9_bead25_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead13/ZeissGreenBeadsIMG4R_Image 9_bead13_data/ZeissGreenBeadsIMG4R_Image 9_bead13_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead14/ZeissGreenBeadsIMG4R_Image 9_bead14_data/ZeissGreenBeadsIMG4R_Image 9_bead14_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead48/ZeissGreenBeadsIMG4R_Image 9_bead48_data/ZeissGreenBeadsIMG4R_Image 9_bead48_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead46/ZeissGreenBeadsIMG4R_Image 9_bead46_data/ZeissGreenBeadsIMG4R_Image 9_bead46_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead41/ZeissGreenBeadsIMG4R_Image 9_bead41_data/ZeissGreenBeadsIMG4R_Image 9_bead41_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead15/ZeissGreenBeadsIMG4R_Image 9_bead15_data/ZeissGreenBeadsIMG4R_Image 9_bead15_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead12/ZeissGreenBeadsIMG4R_Image 9_bead12_data/ZeissGreenBeadsIMG4R_Image 9_bead12_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead24/ZeissGreenBeadsIMG4R_Image 9_bead24_data/ZeissGreenBeadsIMG4R_Image 9_bead24_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead23/ZeissGreenBeadsIMG4R_Image 9_bead23_data/ZeissGreenBeadsIMG4R_Image 9_bead23_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead8/ZeissGreenBeadsIMG4R_Image 9_bead8_data/ZeissGreenBeadsIMG4R_Image 9_bead8_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead1/ZeissGreenBeadsIMG4R_Image 9_bead1_data/ZeissGreenBeadsIMG4R_Image 9_bead1_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead6/ZeissGreenBeadsIMG4R_Image 9_bead6_data/ZeissGreenBeadsIMG4R_Image 9_bead6_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead7/ZeissGreenBeadsIMG4R_Image 9_bead7_data/ZeissGreenBeadsIMG4R_Image 9_bead7_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead0/ZeissGreenBeadsIMG4R_Image 9_bead0_data/ZeissGreenBeadsIMG4R_Image 9_bead0_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead9/ZeissGreenBeadsIMG4R_Image 9_bead9_data/ZeissGreenBeadsIMG4R_Image 9_bead9_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead39/ZeissGreenBeadsIMG4R_Image 9_bead39_data/ZeissGreenBeadsIMG4R_Image 9_bead39_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead30/ZeissGreenBeadsIMG4R_Image 9_bead30_data/ZeissGreenBeadsIMG4R_Image 9_bead30_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead37/ZeissGreenBeadsIMG4R_Image 9_bead37_data/ZeissGreenBeadsIMG4R_Image 9_bead37_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead52/ZeissGreenBeadsIMG4R_Image 9_bead52_data/ZeissGreenBeadsIMG4R_Image 9_bead52_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead55/ZeissGreenBeadsIMG4R_Image 9_bead55_data/ZeissGreenBeadsIMG4R_Image 9_bead55_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead36/ZeissGreenBeadsIMG4R_Image 9_bead36_data/ZeissGreenBeadsIMG4R_Image 9_bead36_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead31/ZeissGreenBeadsIMG4R_Image 9_bead31_data/ZeissGreenBeadsIMG4R_Image 9_bead31_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead38/ZeissGreenBeadsIMG4R_Image 9_bead38_data/ZeissGreenBeadsIMG4R_Image 9_bead38_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead54/ZeissGreenBeadsIMG4R_Image 9_bead54_data/ZeissGreenBeadsIMG4R_Image 9_bead54_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 9/bead53/ZeissGreenBeadsIMG4R_Image 9_bead53_data/ZeissGreenBeadsIMG4R_Image 9_bead53_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead26/ZeissGreenBeadsIMG4R_Image 7_bead26_data/ZeissGreenBeadsIMG4R_Image 7_bead26_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead19/ZeissGreenBeadsIMG4R_Image 7_bead19_data/ZeissGreenBeadsIMG4R_Image 7_bead19_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead21/ZeissGreenBeadsIMG4R_Image 7_bead21_data/ZeissGreenBeadsIMG4R_Image 7_bead21_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead17/ZeissGreenBeadsIMG4R_Image 7_bead17_data/ZeissGreenBeadsIMG4R_Image 7_bead17_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead28/ZeissGreenBeadsIMG4R_Image 7_bead28_data/ZeissGreenBeadsIMG4R_Image 7_bead28_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead10/ZeissGreenBeadsIMG4R_Image 7_bead10_data/ZeissGreenBeadsIMG4R_Image 7_bead10_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead44/ZeissGreenBeadsIMG4R_Image 7_bead44_data/ZeissGreenBeadsIMG4R_Image 7_bead44_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead43/ZeissGreenBeadsIMG4R_Image 7_bead43_data/ZeissGreenBeadsIMG4R_Image 7_bead43_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead11/ZeissGreenBeadsIMG4R_Image 7_bead11_data/ZeissGreenBeadsIMG4R_Image 7_bead11_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead16/ZeissGreenBeadsIMG4R_Image 7_bead16_data/ZeissGreenBeadsIMG4R_Image 7_bead16_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead29/ZeissGreenBeadsIMG4R_Image 7_bead29_data/ZeissGreenBeadsIMG4R_Image 7_bead29_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead20/ZeissGreenBeadsIMG4R_Image 7_bead20_data/ZeissGreenBeadsIMG4R_Image 7_bead20_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead27/ZeissGreenBeadsIMG4R_Image 7_bead27_data/ZeissGreenBeadsIMG4R_Image 7_bead27_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead18/ZeissGreenBeadsIMG4R_Image 7_bead18_data/ZeissGreenBeadsIMG4R_Image 7_bead18_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead42/ZeissGreenBeadsIMG4R_Image 7_bead42_data/ZeissGreenBeadsIMG4R_Image 7_bead42_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead45/ZeissGreenBeadsIMG4R_Image 7_bead45_data/ZeissGreenBeadsIMG4R_Image 7_bead45_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead5/ZeissGreenBeadsIMG4R_Image 7_bead5_data/ZeissGreenBeadsIMG4R_Image 7_bead5_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead2/ZeissGreenBeadsIMG4R_Image 7_bead2_data/ZeissGreenBeadsIMG4R_Image 7_bead2_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead3/ZeissGreenBeadsIMG4R_Image 7_bead3_data/ZeissGreenBeadsIMG4R_Image 7_bead3_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead4/ZeissGreenBeadsIMG4R_Image 7_bead4_data/ZeissGreenBeadsIMG4R_Image 7_bead4_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead34/ZeissGreenBeadsIMG4R_Image 7_bead34_data/ZeissGreenBeadsIMG4R_Image 7_bead34_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead33/ZeissGreenBeadsIMG4R_Image 7_bead33_data/ZeissGreenBeadsIMG4R_Image 7_bead33_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead32/ZeissGreenBeadsIMG4R_Image 7_bead32_data/ZeissGreenBeadsIMG4R_Image 7_bead32_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead35/ZeissGreenBeadsIMG4R_Image 7_bead35_data/ZeissGreenBeadsIMG4R_Image 7_bead35_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead40/ZeissGreenBeadsIMG4R_Image 7_bead40_data/ZeissGreenBeadsIMG4R_Image 7_bead40_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead22/ZeissGreenBeadsIMG4R_Image 7_bead22_data/ZeissGreenBeadsIMG4R_Image 7_bead22_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead25/ZeissGreenBeadsIMG4R_Image 7_bead25_data/ZeissGreenBeadsIMG4R_Image 7_bead25_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead13/ZeissGreenBeadsIMG4R_Image 7_bead13_data/ZeissGreenBeadsIMG4R_Image 7_bead13_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead14/ZeissGreenBeadsIMG4R_Image 7_bead14_data/ZeissGreenBeadsIMG4R_Image 7_bead14_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead41/ZeissGreenBeadsIMG4R_Image 7_bead41_data/ZeissGreenBeadsIMG4R_Image 7_bead41_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead15/ZeissGreenBeadsIMG4R_Image 7_bead15_data/ZeissGreenBeadsIMG4R_Image 7_bead15_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead12/ZeissGreenBeadsIMG4R_Image 7_bead12_data/ZeissGreenBeadsIMG4R_Image 7_bead12_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead24/ZeissGreenBeadsIMG4R_Image 7_bead24_data/ZeissGreenBeadsIMG4R_Image 7_bead24_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead23/ZeissGreenBeadsIMG4R_Image 7_bead23_data/ZeissGreenBeadsIMG4R_Image 7_bead23_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead8/ZeissGreenBeadsIMG4R_Image 7_bead8_data/ZeissGreenBeadsIMG4R_Image 7_bead8_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead1/ZeissGreenBeadsIMG4R_Image 7_bead1_data/ZeissGreenBeadsIMG4R_Image 7_bead1_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead6/ZeissGreenBeadsIMG4R_Image 7_bead6_data/ZeissGreenBeadsIMG4R_Image 7_bead6_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead7/ZeissGreenBeadsIMG4R_Image 7_bead7_data/ZeissGreenBeadsIMG4R_Image 7_bead7_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead0/ZeissGreenBeadsIMG4R_Image 7_bead0_data/ZeissGreenBeadsIMG4R_Image 7_bead0_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead9/ZeissGreenBeadsIMG4R_Image 7_bead9_data/ZeissGreenBeadsIMG4R_Image 7_bead9_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead39/ZeissGreenBeadsIMG4R_Image 7_bead39_data/ZeissGreenBeadsIMG4R_Image 7_bead39_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead30/ZeissGreenBeadsIMG4R_Image 7_bead30_data/ZeissGreenBeadsIMG4R_Image 7_bead30_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead37/ZeissGreenBeadsIMG4R_Image 7_bead37_data/ZeissGreenBeadsIMG4R_Image 7_bead37_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead36/ZeissGreenBeadsIMG4R_Image 7_bead36_data/ZeissGreenBeadsIMG4R_Image 7_bead36_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead31/ZeissGreenBeadsIMG4R_Image 7_bead31_data/ZeissGreenBeadsIMG4R_Image 7_bead31_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 7/bead38/ZeissGreenBeadsIMG4R_Image 7_bead38_data/ZeissGreenBeadsIMG4R_Image 7_bead38_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 6/bead5/ZeissGreenBeadsIMG4R_Image 6_bead5_data/ZeissGreenBeadsIMG4R_Image 6_bead5_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 6/bead2/ZeissGreenBeadsIMG4R_Image 6_bead2_data/ZeissGreenBeadsIMG4R_Image 6_bead2_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 6/bead3/ZeissGreenBeadsIMG4R_Image 6_bead3_data/ZeissGreenBeadsIMG4R_Image 6_bead3_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 6/bead4/ZeissGreenBeadsIMG4R_Image 6_bead4_data/ZeissGreenBeadsIMG4R_Image 6_bead4_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 6/bead8/ZeissGreenBeadsIMG4R_Image 6_bead8_data/ZeissGreenBeadsIMG4R_Image 6_bead8_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 6/bead1/ZeissGreenBeadsIMG4R_Image 6_bead1_data/ZeissGreenBeadsIMG4R_Image 6_bead1_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 6/bead6/ZeissGreenBeadsIMG4R_Image 6_bead6_data/ZeissGreenBeadsIMG4R_Image 6_bead6_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 6/bead7/ZeissGreenBeadsIMG4R_Image 6_bead7_data/ZeissGreenBeadsIMG4R_Image 6_bead7_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 6/bead0/ZeissGreenBeadsIMG4R_Image 6_bead0_data/ZeissGreenBeadsIMG4R_Image 6_bead0_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 6/bead9/ZeissGreenBeadsIMG4R_Image 6_bead9_data/ZeissGreenBeadsIMG4R_Image 6_bead9_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 1/bead0/ZeissGreenBeadsIMG4R_Image 1_bead0_data/ZeissGreenBeadsIMG4R_Image 1_bead0_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead26/ZeissGreenBeadsIMG4R_Image 8_bead26_data/ZeissGreenBeadsIMG4R_Image 8_bead26_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead19/ZeissGreenBeadsIMG4R_Image 8_bead19_data/ZeissGreenBeadsIMG4R_Image 8_bead19_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead21/ZeissGreenBeadsIMG4R_Image 8_bead21_data/ZeissGreenBeadsIMG4R_Image 8_bead21_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead17/ZeissGreenBeadsIMG4R_Image 8_bead17_data/ZeissGreenBeadsIMG4R_Image 8_bead17_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead28/ZeissGreenBeadsIMG4R_Image 8_bead28_data/ZeissGreenBeadsIMG4R_Image 8_bead28_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead10/ZeissGreenBeadsIMG4R_Image 8_bead10_data/ZeissGreenBeadsIMG4R_Image 8_bead10_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead11/ZeissGreenBeadsIMG4R_Image 8_bead11_data/ZeissGreenBeadsIMG4R_Image 8_bead11_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead16/ZeissGreenBeadsIMG4R_Image 8_bead16_data/ZeissGreenBeadsIMG4R_Image 8_bead16_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead29/ZeissGreenBeadsIMG4R_Image 8_bead29_data/ZeissGreenBeadsIMG4R_Image 8_bead29_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead20/ZeissGreenBeadsIMG4R_Image 8_bead20_data/ZeissGreenBeadsIMG4R_Image 8_bead20_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead27/ZeissGreenBeadsIMG4R_Image 8_bead27_data/ZeissGreenBeadsIMG4R_Image 8_bead27_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead18/ZeissGreenBeadsIMG4R_Image 8_bead18_data/ZeissGreenBeadsIMG4R_Image 8_bead18_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead5/ZeissGreenBeadsIMG4R_Image 8_bead5_data/ZeissGreenBeadsIMG4R_Image 8_bead5_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead2/ZeissGreenBeadsIMG4R_Image 8_bead2_data/ZeissGreenBeadsIMG4R_Image 8_bead2_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead3/ZeissGreenBeadsIMG4R_Image 8_bead3_data/ZeissGreenBeadsIMG4R_Image 8_bead3_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead4/ZeissGreenBeadsIMG4R_Image 8_bead4_data/ZeissGreenBeadsIMG4R_Image 8_bead4_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead34/ZeissGreenBeadsIMG4R_Image 8_bead34_data/ZeissGreenBeadsIMG4R_Image 8_bead34_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead33/ZeissGreenBeadsIMG4R_Image 8_bead33_data/ZeissGreenBeadsIMG4R_Image 8_bead33_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead32/ZeissGreenBeadsIMG4R_Image 8_bead32_data/ZeissGreenBeadsIMG4R_Image 8_bead32_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead35/ZeissGreenBeadsIMG4R_Image 8_bead35_data/ZeissGreenBeadsIMG4R_Image 8_bead35_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead22/ZeissGreenBeadsIMG4R_Image 8_bead22_data/ZeissGreenBeadsIMG4R_Image 8_bead22_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead25/ZeissGreenBeadsIMG4R_Image 8_bead25_data/ZeissGreenBeadsIMG4R_Image 8_bead25_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead13/ZeissGreenBeadsIMG4R_Image 8_bead13_data/ZeissGreenBeadsIMG4R_Image 8_bead13_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead14/ZeissGreenBeadsIMG4R_Image 8_bead14_data/ZeissGreenBeadsIMG4R_Image 8_bead14_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead15/ZeissGreenBeadsIMG4R_Image 8_bead15_data/ZeissGreenBeadsIMG4R_Image 8_bead15_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead12/ZeissGreenBeadsIMG4R_Image 8_bead12_data/ZeissGreenBeadsIMG4R_Image 8_bead12_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead24/ZeissGreenBeadsIMG4R_Image 8_bead24_data/ZeissGreenBeadsIMG4R_Image 8_bead24_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead23/ZeissGreenBeadsIMG4R_Image 8_bead23_data/ZeissGreenBeadsIMG4R_Image 8_bead23_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead8/ZeissGreenBeadsIMG4R_Image 8_bead8_data/ZeissGreenBeadsIMG4R_Image 8_bead8_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead1/ZeissGreenBeadsIMG4R_Image 8_bead1_data/ZeissGreenBeadsIMG4R_Image 8_bead1_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead6/ZeissGreenBeadsIMG4R_Image 8_bead6_data/ZeissGreenBeadsIMG4R_Image 8_bead6_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead7/ZeissGreenBeadsIMG4R_Image 8_bead7_data/ZeissGreenBeadsIMG4R_Image 8_bead7_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead0/ZeissGreenBeadsIMG4R_Image 8_bead0_data/ZeissGreenBeadsIMG4R_Image 8_bead0_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead9/ZeissGreenBeadsIMG4R_Image 8_bead9_data/ZeissGreenBeadsIMG4R_Image 8_bead9_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead30/ZeissGreenBeadsIMG4R_Image 8_bead30_data/ZeissGreenBeadsIMG4R_Image 8_bead30_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead37/ZeissGreenBeadsIMG4R_Image 8_bead37_data/ZeissGreenBeadsIMG4R_Image 8_bead37_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead36/ZeissGreenBeadsIMG4R_Image 8_bead36_data/ZeissGreenBeadsIMG4R_Image 8_bead36_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 8/bead31/ZeissGreenBeadsIMG4R_Image 8_bead31_data/ZeissGreenBeadsIMG4R_Image 8_bead31_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead26/ZeissGreenBeadsIMG4R_Image 10_bead26_data/ZeissGreenBeadsIMG4R_Image 10_bead26_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead19/ZeissGreenBeadsIMG4R_Image 10_bead19_data/ZeissGreenBeadsIMG4R_Image 10_bead19_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead21/ZeissGreenBeadsIMG4R_Image 10_bead21_data/ZeissGreenBeadsIMG4R_Image 10_bead21_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead17/ZeissGreenBeadsIMG4R_Image 10_bead17_data/ZeissGreenBeadsIMG4R_Image 10_bead17_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead28/ZeissGreenBeadsIMG4R_Image 10_bead28_data/ZeissGreenBeadsIMG4R_Image 10_bead28_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead10/ZeissGreenBeadsIMG4R_Image 10_bead10_data/ZeissGreenBeadsIMG4R_Image 10_bead10_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead44/ZeissGreenBeadsIMG4R_Image 10_bead44_data/ZeissGreenBeadsIMG4R_Image 10_bead44_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead43/ZeissGreenBeadsIMG4R_Image 10_bead43_data/ZeissGreenBeadsIMG4R_Image 10_bead43_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead11/ZeissGreenBeadsIMG4R_Image 10_bead11_data/ZeissGreenBeadsIMG4R_Image 10_bead11_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead16/ZeissGreenBeadsIMG4R_Image 10_bead16_data/ZeissGreenBeadsIMG4R_Image 10_bead16_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead29/ZeissGreenBeadsIMG4R_Image 10_bead29_data/ZeissGreenBeadsIMG4R_Image 10_bead29_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead20/ZeissGreenBeadsIMG4R_Image 10_bead20_data/ZeissGreenBeadsIMG4R_Image 10_bead20_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead27/ZeissGreenBeadsIMG4R_Image 10_bead27_data/ZeissGreenBeadsIMG4R_Image 10_bead27_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead18/ZeissGreenBeadsIMG4R_Image 10_bead18_data/ZeissGreenBeadsIMG4R_Image 10_bead18_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead42/ZeissGreenBeadsIMG4R_Image 10_bead42_data/ZeissGreenBeadsIMG4R_Image 10_bead42_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead45/ZeissGreenBeadsIMG4R_Image 10_bead45_data/ZeissGreenBeadsIMG4R_Image 10_bead45_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead5/ZeissGreenBeadsIMG4R_Image 10_bead5_data/ZeissGreenBeadsIMG4R_Image 10_bead5_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead2/ZeissGreenBeadsIMG4R_Image 10_bead2_data/ZeissGreenBeadsIMG4R_Image 10_bead2_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead3/ZeissGreenBeadsIMG4R_Image 10_bead3_data/ZeissGreenBeadsIMG4R_Image 10_bead3_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead4/ZeissGreenBeadsIMG4R_Image 10_bead4_data/ZeissGreenBeadsIMG4R_Image 10_bead4_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead51/ZeissGreenBeadsIMG4R_Image 10_bead51_data/ZeissGreenBeadsIMG4R_Image 10_bead51_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead34/ZeissGreenBeadsIMG4R_Image 10_bead34_data/ZeissGreenBeadsIMG4R_Image 10_bead34_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead33/ZeissGreenBeadsIMG4R_Image 10_bead33_data/ZeissGreenBeadsIMG4R_Image 10_bead33_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead50/ZeissGreenBeadsIMG4R_Image 10_bead50_data/ZeissGreenBeadsIMG4R_Image 10_bead50_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead32/ZeissGreenBeadsIMG4R_Image 10_bead32_data/ZeissGreenBeadsIMG4R_Image 10_bead32_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead35/ZeissGreenBeadsIMG4R_Image 10_bead35_data/ZeissGreenBeadsIMG4R_Image 10_bead35_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead40/ZeissGreenBeadsIMG4R_Image 10_bead40_data/ZeissGreenBeadsIMG4R_Image 10_bead40_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead47/ZeissGreenBeadsIMG4R_Image 10_bead47_data/ZeissGreenBeadsIMG4R_Image 10_bead47_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead49/ZeissGreenBeadsIMG4R_Image 10_bead49_data/ZeissGreenBeadsIMG4R_Image 10_bead49_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead22/ZeissGreenBeadsIMG4R_Image 10_bead22_data/ZeissGreenBeadsIMG4R_Image 10_bead22_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead25/ZeissGreenBeadsIMG4R_Image 10_bead25_data/ZeissGreenBeadsIMG4R_Image 10_bead25_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead13/ZeissGreenBeadsIMG4R_Image 10_bead13_data/ZeissGreenBeadsIMG4R_Image 10_bead13_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead14/ZeissGreenBeadsIMG4R_Image 10_bead14_data/ZeissGreenBeadsIMG4R_Image 10_bead14_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead48/ZeissGreenBeadsIMG4R_Image 10_bead48_data/ZeissGreenBeadsIMG4R_Image 10_bead48_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead46/ZeissGreenBeadsIMG4R_Image 10_bead46_data/ZeissGreenBeadsIMG4R_Image 10_bead46_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead41/ZeissGreenBeadsIMG4R_Image 10_bead41_data/ZeissGreenBeadsIMG4R_Image 10_bead41_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead15/ZeissGreenBeadsIMG4R_Image 10_bead15_data/ZeissGreenBeadsIMG4R_Image 10_bead15_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead12/ZeissGreenBeadsIMG4R_Image 10_bead12_data/ZeissGreenBeadsIMG4R_Image 10_bead12_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead24/ZeissGreenBeadsIMG4R_Image 10_bead24_data/ZeissGreenBeadsIMG4R_Image 10_bead24_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead23/ZeissGreenBeadsIMG4R_Image 10_bead23_data/ZeissGreenBeadsIMG4R_Image 10_bead23_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead8/ZeissGreenBeadsIMG4R_Image 10_bead8_data/ZeissGreenBeadsIMG4R_Image 10_bead8_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead1/ZeissGreenBeadsIMG4R_Image 10_bead1_data/ZeissGreenBeadsIMG4R_Image 10_bead1_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead6/ZeissGreenBeadsIMG4R_Image 10_bead6_data/ZeissGreenBeadsIMG4R_Image 10_bead6_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead7/ZeissGreenBeadsIMG4R_Image 10_bead7_data/ZeissGreenBeadsIMG4R_Image 10_bead7_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead0/ZeissGreenBeadsIMG4R_Image 10_bead0_data/ZeissGreenBeadsIMG4R_Image 10_bead0_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead9/ZeissGreenBeadsIMG4R_Image 10_bead9_data/ZeissGreenBeadsIMG4R_Image 10_bead9_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead39/ZeissGreenBeadsIMG4R_Image 10_bead39_data/ZeissGreenBeadsIMG4R_Image 10_bead39_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead30/ZeissGreenBeadsIMG4R_Image 10_bead30_data/ZeissGreenBeadsIMG4R_Image 10_bead30_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead37/ZeissGreenBeadsIMG4R_Image 10_bead37_data/ZeissGreenBeadsIMG4R_Image 10_bead37_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead52/ZeissGreenBeadsIMG4R_Image 10_bead52_data/ZeissGreenBeadsIMG4R_Image 10_bead52_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead36/ZeissGreenBeadsIMG4R_Image 10_bead36_data/ZeissGreenBeadsIMG4R_Image 10_bead36_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead31/ZeissGreenBeadsIMG4R_Image 10_bead31_data/ZeissGreenBeadsIMG4R_Image 10_bead31_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead38/ZeissGreenBeadsIMG4R_Image 10_bead38_data/ZeissGreenBeadsIMG4R_Image 10_bead38_results.xls not found
#
# Error: ZeissGreenBeadsIMG4R/Image 10/bead53/ZeissGreenBeadsIMG4R_Image 10_bead53_data/ZeissGreenBeadsIMG4R_Image 10_bead53_results.xls not found
# X Ratios: []
# Y Ratios: []
# Z Ratios: []
# Lateral Asymmetries: []

# %%
#Kirging Interpolation
variogram_model = "spherical" #linear, power, gaussian, spherical, exponential, hole-effect

# %%
def is_complete_bead(bead):
    return (
        all(dim in bead["Mes./theory ratio"] for dim in ['X', 'Y', 'Z']) and
        bead["Lateral Asymmetry"] is not None and
        "X" in bead["Bead coordinates (pixels)"] and
        "Y" in bead["Bead coordinates (pixels)"]
    )

# Separate complete and incomplete beads
complete_beads = [bead for bead in beads_list if is_complete_bead(bead)]
incomplete_beads = [bead for bead in beads_list if not is_complete_bead(bead)]

# Extract data from complete beads
x = np.array([bead["Bead coordinates (pixels)"]["X"] for bead in complete_beads])
y = np.array([bead["Bead coordinates (pixels)"]["Y"] for bead in complete_beads])
z_x = np.array([bead["Mes./theory ratio"]["X"] for bead in complete_beads])
z_y = np.array([bead["Mes./theory ratio"]["Y"] for bead in complete_beads])
z_z = np.array([bead["Mes./theory ratio"]["Z"] for bead in complete_beads])
z_lat = np.array([bead["Lateral Asymmetry"] for bead in complete_beads])

# Precompute min and max for x and y
x_min, x_max = min(x), max(x)
y_min, y_max = min(y), max(y)

# Create meshgrid for interpolation
xi, yi = np.meshgrid(np.linspace(x_min, x_max, 100), np.linspace(y_min, y_max, 100))

# Function to perform Kriging interpolation
def kriging_interpolation(x, y, z_values, xi, yi):
    OK = OrdinaryKriging(x, y, z_values, variogram_model=variogram_model, verbose=False, enable_plotting=False)
    zi, ss = OK.execute('grid', np.linspace(x_min, x_max, 100), np.linspace(y_min, y_max, 100))
    return zi

# Perform Kriging interpolation
zi_x = kriging_interpolation(x, y, z_x, xi, yi)
zi_y = kriging_interpolation(x, y, z_y, xi, yi)
zi_z = kriging_interpolation(x, y, z_z, xi, yi)
zi_lat = kriging_interpolation(x, y, z_lat, xi, yi)

# Plotting function
def plot_heatmap(ax, zi, title, z_values):
    im = ax.imshow(zi, extent=[x_min, x_max, y_max, y_min], origin='upper', cmap=cmap, vmin=vmin, vmax=vmax)
    ax.set_title(title)
    ax.set_xlabel('X position')
    ax.set_ylabel('Y position')

    # Scatter plot for complete beads
    ax.scatter(x, y, c='red', s=10, label='Complete data')

    # Scatter plot for incomplete beads
    for bead in incomplete_beads:
        if "X" in bead["Bead coordinates (pixels)"] and "Y" in bead["Bead coordinates (pixels)"]:
            if title.split()[0] in bead["Mes./theory ratio"] or (title == "Lateral Asymmetry" and bead["Lateral Asymmetry"] is not None):
                ax.scatter(bead["Bead coordinates (pixels)"]["X"], bead["Bead coordinates (pixels)"]["Y"], c='red', s=10)
            else:
                ax.scatter(bead["Bead coordinates (pixels)"]["X"], bead["Bead coordinates (pixels)"]["Y"], c='gray', s=10, alpha=0.5)

    # Add colorbar
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(im, cax=cax)

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(20, 20))

# Plot the four heatmaps with Kriging interpolation
plot_heatmap(axs[0, 0], zi_x, 'X FWHM / Theoretical (Kriging)', z_x)
plot_heatmap(axs[0, 1], zi_y, 'Y FWHM / Theoretical (Kriging)', z_y)
plot_heatmap(axs[1, 0], zi_z, 'Z FWHM / Theoretical (Kriging)', z_z)
plot_heatmap(axs[1, 1], zi_lat, 'Lateral Asymmetry (Kriging)', z_lat)

# Tight layout for spacing
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[193], line 22
#      19 z_lat = np.array([bead["Lateral Asymmetry"] for bead in complete_beads])
#      21 # Precompute min and max for x and y
# ---> 22 x_min, x_max = min(x), max(x)
#      23 y_min, y_max = min(y), max(y)
#      25 # Create meshgrid for interpolation
#
# ValueError: min() iterable argument is empty

# %%
#another interpolation
method='cubic' #linear etc

# %%
# Separate complete and incomplete beads
complete_beads = []
incomplete_beads = []
    
for bead in beads_list:
    if (all(dim in bead["Mes./theory ratio"] for dim in ['X', 'Y', 'Z']) and
        bead["Lateral Asymmetry"] is not None and
        "X" in bead["Bead coordinates (pixels)"] and
        "Y" in bead["Bead coordinates (pixels)"]):
        complete_beads.append(bead)
    else:
        incomplete_beads.append(bead)

# Extract data
x = [bead["Bead coordinates (pixels)"]["X"] for bead in complete_beads]
y = [bead["Bead coordinates (pixels)"]["Y"] for bead in complete_beads]
z_x = [bead["Mes./theory ratio"]["X"] for bead in complete_beads]
z_y = [bead["Mes./theory ratio"]["Y"] for bead in complete_beads]
z_z = [bead["Mes./theory ratio"]["Z"] for bead in complete_beads]
z_lat = [bead["Lateral Asymmetry"] for bead in complete_beads]

# Create meshgrid
xi = np.linspace(min(x), max(x), 100)
yi = np.linspace(min(y), max(y), 100)
xi, yi = np.meshgrid(xi, yi)

# Interpolate data
zi_x = griddata((x, y), z_x, (xi, yi), method=method)
zi_y = griddata((x, y), z_y, (xi, yi), method=method)
zi_z = griddata((x, y), z_z, (xi, yi), method=method)
zi_lat = griddata((x, y), z_lat, (xi, yi), method=method)

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(20, 20))
    
def plot_heatmap(ax, zi, title, z_values):
    im = ax.imshow(zi, extent=[min(x), max(x), max(y), min(y)], origin='upper', cmap=cmap, vmin=vmin, vmax=vmax)
    ax.set_title(title)
    ax.set_xlabel('X position')
    ax.set_ylabel('Y position')

    # Plot complete data
    ax.scatter(x, y, c='red', s=10, label='Complete data')

    # Plot incomplete data
    for bead in incomplete_beads:
        if "X" in bead["Bead coordinates (pixels)"] and "Y" in bead["Bead coordinates (pixels)"]:
            if title.split()[0] in bead["Mes./theory ratio"] or (title == "Lateral Asymmetry" and bead["Lateral Asymmetry"] is not None):
                ax.scatter(bead["Bead coordinates (pixels)"]["X"], bead["Bead coordinates (pixels)"]["Y"], c='red', s=10)
            else:
                ax.scatter(bead["Bead coordinates (pixels)"]["X"], bead["Bead coordinates (pixels)"]["Y"], c='gray', s=10, alpha=0.5)

    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(im, cax=cax)

# Plot heatmaps
plot_heatmap(axs[0, 0], zi_x, 'X FWHM / Theoretical', z_x)
plot_heatmap(axs[0, 1], zi_y, 'Y FWHM / Theoretical', z_y)
plot_heatmap(axs[1, 0], zi_z, 'Z FWHM / Theoretical', z_z)
plot_heatmap(axs[1, 1], zi_lat, 'Lateral Asymmetry', z_lat)

plt.tight_layout()
plt.show()
